# %%
#Martix Arithmetic

# %%
import numpy as np

# %%
a = np.array([1, 4, 5])

# %%
b = np.array([-1, 4, 53])

# %%
c = a + b

# %%
d = a * b

# %%
c
# Out:
# array([ 0,  8, 58])

# %%
d
# Out:
# array([ -1,  16, 265])

# %%
m1 = np.array([[1, 4], [-5, 8]])

# %%
m2 = ([[7, -6], [-11, 2]])

# %%
msum = m1 + m2

# %%
product = np.dot(m1, m2)

# %%
msum
# Out:
# array([[  8,  -2],
#        [-16,  10]])

# %%
product
# Out:
# array([[ -37,    2],
#        [-123,   46]])

# %%
#Null martix

# %%
zeros = np.zeros((2,3))

# %%
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
#Identity martix

# %%
i = np.identity(3)

# %%
i
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
